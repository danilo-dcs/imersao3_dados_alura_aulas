# %% [markdown]
# <a href="https://colab.research.google.com/github/danilo-dcs/imersao_dados_alura/blob/main/Aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importando panda e carregando a base de dados
import pandas as pd
import matplotlib.pyplot as plt

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression='zip')

# imprimindo base de dados
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
# pega o cabeçalho da tabela (5 primeiras linhas)
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
# prega o tamanho da tabela de dados
dados.shape
# Out:
# (23814, 877)

# %%
#pega a coluna "tratamento"
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
# pega na coluna de dados, o cunjunto dos valores que aparecem, sem repetir
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
# pega na coluna de dados, o cunjunto dos valores que aparecem, sem repetir
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
# pega na coluna de dados, o cunjunto dos valores que aparecem, sem repetir
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
# pega na coluna de dados, o cunjunto dos valores que aparecem, sem repetir
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
# pega na coluna de dados, o cunjunto dos valores que aparecem, sem repetir
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
# contar a frequência de ocorrência dos valores de tratamento
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
# Normalizar a frequência de ocorrência dos valores de tratamento
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
# contar a frequência de ocorrência dos valores de dose
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
# Normalizar a frequência de ocorrência dos valores de dose
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
# construção de gráfico PIZZA com os valores de tratamento
dados['tratamento'].value_counts().plot.pie()

# %%
# construção de gráfico PIZZA com os valores de tempo
dados['tempo'].value_counts().plot.pie()

# %%
# construção de gráfico BARRAR com os valores de tratamento
dados['tempo'].value_counts().plot.bar()

# %%
# selecionando os elementos da colna g-0 maiores do que 0
dados['g-0'] > 0
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 23809     True
# 23810    False
# 23811     True
# 23812     True
# 23813    False
# Name: g-0, Length: 23814, dtype: bool

# %%
# selecionando os elementos da colna g-0 maiores do que 0 sem exibir true or false e imprimindo a tabela
dados[dados['g-0'] > 0]
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6      id_001bd861f     com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23807  id_fff7e6992     com_droga     48   D1  ...  0.3738  0.8636  0.4494  0.1218
# 23808  id_fff8c2444     com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
# imprimindo o cabeçalho dos dados filtrados
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# ********************************************************************************
# ********************************************************************************
#
# ### **Desafio 1:** Investigar por que a classe tratamento é tão desbalanceada
#
# ### **Desafio 2:** Plotar as 5 últimas linhas da tabela
#
# ### **Desafio 3:** Calcular a proporção das classes tratamento olhar na Doc
#
# ### **Desafio 4 :** Quantos tipos de drogas foram investigados
#
# ### **Desafio 5:** Procurar o método query para filtragem. Doc: Pandas
#
# ### **Desafio 6:** Renomear as colunas com hífen.
#
# ### **Desafio 7:** Colocar título e labels nos gráficos. Doc: Matplotlib

# %%
### DESAFIO 1
counts = dados['tratamento'].value_counts(normalize = True)

com_droga = counts[0]
sem_droga = counts[1]

print(f'Porcentagem de tratamento com droga: {(com_droga*100):.2f} %')
print(f'Porcentagem de tratamento sem droga: {(sem_droga*100):.2f} %')
# Out:
# Porcentagem de tratamento com droga: 92.16 %
# Porcentagem de tratamento sem droga: 7.84 %

# %%
### DESAFIO 2
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %%
### DESAFIO 3

counts = dados['tratamento'].value_counts(normalize = True)

com_droga = counts[0]
sem_droga = counts[1]

print(f'PROPORÇÃO DE X TRATAMENTOS SEM DROGA A CADA Y COM DROGA : {1:.2f} - {((com_droga*100)/(sem_droga*100)) :.2f}')
# Out:
# PROPORÇÃO DE X TRATAMENTOS SEM DROGA A CADA Y COM DROGA : 1.00 - 11.76

# %%
### DESAFIO 4

qtdDrogas = dados['droga'].unique()

print("Quantidades de drogas utilizadas: ")
tam = len(qtdDrogas)
print(tam)

qtdNunique = dados.droga.nunique()
print("Quantidade de drogas com o nunique")
print(qtdNunique)
# Out:
# Quantidades de drogas utilizadas:
# 3289
# Quantidade de drogas com o nunique
# 3289

# %%
### DESAFIO 5
# aplicar a query para encontrar dados de tempo maiores do que 40

dados.query('tempo > 40')
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23806  id_fff790a17     com_droga     48   D2  ...  1.2630  0.7823 -0.6947  0.7277
# 23807  id_fff7e6992     com_droga     48   D1  ...  0.3738  0.8636  0.4494  0.1218
# 23808  id_fff8c2444     com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
### DESAFIO 6

#dados.rename(columns={dados.columns : dados.columns.str.replace("-","_") }, inplace=False)
dados.columns = dados.columns.str.replace('-','_')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c_96    c_97    c_98    c_99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
### DESAFIO 7
# Replicar o plot do gráfico de barras anterior, porém com a matplot lib e
# adicionando detalhes
plt.close("all")
dados_plot = dados['tempo'].value_counts()

dados_plot.plot(title='Grafico' ,xlabel='Horas',ylabel='Quantidade' , kind='bar')


# plt.figure()
